# %%
# !rm -rf * .* 2>/dev/null
# !rm -rf ~/.kaggle && mkdir ~/.kaggle
# !echo eyJ1c2VybmFtZSI6InB2dHNlYzB4MSIsImtleSI6IjZlOTYxZmMxYjdhYzU2OTlmNzcwYmFjMjI1NTk4MWIwIn0= | base64 -d > ~/.kaggle/kaggle.json
# !git clone https://github.com/Reshmavineesh/SunLit-Segmentation .
# !git checkout dev
# !./download_dataset.sh
from IPython.display import clear_output
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'; clear_output()
print("Dataset ready")
# Out:
# Dataset ready

# %%
import utils
import tensorflow as tf

image_path = 'dataset/dataset_pistachio_128/color_images/'
mask_path = 'dataset/dataset_pistachio_128/masks/'
n_val = 100

train_images, train_masks, test_images, test_masks = utils.load_dataset(image_path, mask_path, n_val)
print(f"Train Images:\t{train_images.shape}")
print(f"Train Masks:\t{train_masks.shape}")
print(f"Test Images:\t{test_images.shape}")
print(f"Test Masks:\t{test_masks.shape}")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train Images:	(7250, 128, 128, 3)
# Train Masks:	(7250, 128, 128)
# Test Images:	(100, 128, 128, 3)
# Test Masks:	(100, 128, 128)

# %%
from keras_models.models import SegNet
from tensorflow.keras.callbacks import EarlyStopping


EPOCHS = 200
LEARNING_RATE = 0.001
BATCH_SIZE = 16
early_stopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
loss=utils.dice_loss
metrics = ['accuracy']
input_shape = train_images.shape[1:]

train_attr = {
    "lr": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": optimizer.get_config()['name'],
    "loss_fn": loss.get_config()['name']
}

model = SegNet(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(train_images,
                    train_masks,
                    validation_split = 0.25,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/200
# 340/340 [==============================] - 117s 270ms/step - loss: 0.6361 - accuracy: 0.7625 - val_loss: 0.6819 - val_accuracy: 0.8354
# Epoch 2/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.5815 - accuracy: 0.8068 - val_loss: 0.6790 - val_accuracy: 0.8769
# Epoch 3/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.5416 - accuracy: 0.8278 - val_loss: 0.6152 - val_accuracy: 0.7770
# Epoch 4/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.5224 - accuracy: 0.8315 - val_loss: 0.6762 - val_accuracy: 0.8278
# Epoch 5/200
# 340/340 [==============================] - 89s 261ms/step - loss: 0.5045 - accuracy: 0.8358 - val_loss: 0.5683 - val_accuracy: 0.8052
# Epoch 6/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4791 - accuracy: 0.8434 - val_loss: 0.5410 - val_accuracy: 0.8341
# Epoch 7/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4660 - accuracy: 0.8475 - val_loss: 0.5089 - val_accuracy: 0.8577
# Epoch 8/200
# 340/340 [==============================] - 88s 259ms/step - loss: 0.4560 - accuracy: 0.8509 - val_loss: 0.5040 - val_accuracy: 0.8700
# Epoch 9/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4458 - accuracy: 0.8545 - val_loss: 0.4978 - val_accuracy: 0.8512
# Epoch 10/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4396 - accuracy: 0.8563 - val_loss: 0.4990 - val_accuracy: 0.8886
# Epoch 11/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4854 - accuracy: 0.8371 - val_loss: 0.5232 - val_accuracy: 0.8375
# Epoch 12/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4508 - accuracy: 0.8510 - val_loss: 0.5011 - val_accuracy: 0.8527
# Epoch 13/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4445 - accuracy: 0.8539 - val_loss: 0.4804 - val_accuracy: 0.8831
# Epoch 14/200
# 340/340 [==============================] - 89s 261ms/step - loss: 0.4388 - accuracy: 0.8559 - val_loss: 0.4819 - val_accuracy: 0.8752
# Epoch 15/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4388 - accuracy: 0.8574 - val_loss: 0.5650 - val_accuracy: 0.7649
# Epoch 16/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4520 - accuracy: 0.8554 - val_loss: 0.4998 - val_accuracy: 0.8813
# Epoch 17/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4590 - accuracy: 0.8540 - val_loss: 0.5321 - val_accuracy: 0.8930
# Epoch 18/200
# 340/340 [==============================] - 89s 261ms/step - loss: 0.4458 - accuracy: 0.8559 - val_loss: 0.4909 - val_accuracy: 0.8648
# Epoch 19/200
# 340/340 [==============================] - 89s 262ms/step - loss: 0.4394 - accuracy: 0.8571 - val_loss: 0.6110 - val_accuracy: 0.7144
# Epoch 20/200
# 340/340 [==============================] - 90s 266ms/step - loss: 0.4570 - accuracy: 0.8492 - val_loss: 0.6036 - val_accuracy: 0.7400
# Epoch 21/200
# 340/340 [==============================] - 88s 259ms/step - loss: 0.4565 - accuracy: 0.8442 - val_loss: 0.4875 - val_accuracy: 0.8646
# Epoch 22/200
# 340/340 [==============================] - 88s 260ms/step - loss: 0.4381 - accuracy: 0.8513 - val_loss: 0.5926 - val_accuracy: 0.8837
# Epoch 23/200
# 340/340 [==============================] - ETA: 0s - loss: 0.4321 - accuracy: 0.8546Restoring model weights from the end of the best epoch: 13.
# 340/340 [==============================] - 89s 262ms/step - loss: 0.4321 - accuracy: 0.8546 - val_loss: 0.4835 - val_accuracy: 0.8523
# Epoch 23: early stopping

# %%
utils.analyzer(history, model, image_path, mask_path, test_images, test_masks, train_attr)
# Out:
# 4/4 [==============================] - 3s 357ms/step - loss: 0.6215 - accuracy: 0.8714
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
