# %%
# !rm -rf * .* 2>/dev/null
# !rm -rf ~/.kaggle && mkdir ~/.kaggle
# !echo eyJ1c2VybmFtZSI6InB2dHNlYzB4MSIsImtleSI6IjZlOTYxZmMxYjdhYzU2OTlmNzcwYmFjMjI1NTk4MWIwIn0= | base64 -d > ~/.kaggle/kaggle.json
# !git clone https://github.com/Reshmavineesh/SunLit-Segmentation .
# !git checkout dev
# !./download_dataset.sh
from IPython.display import clear_output
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'; clear_output()
print("Dataset ready")
# Out:
# Dataset ready

# %%
import utils
import tensorflow as tf

image_path = 'dataset/dataset_tomato_128/color_images/'
mask_path = 'dataset/dataset_tomato_128/masks/'
n_val = 125

train_images, train_masks, test_images, test_masks = utils.load_dataset(image_path, mask_path, n_val)
print(f"Train Images:\t{train_images.shape}")
print(f"Train Masks:\t{train_masks.shape}")
print(f"Test Images:\t{test_images.shape}")
print(f"Test Masks:\t{test_masks.shape}")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train Images:	(4723, 128, 128, 3)
# Train Masks:	(4723, 128, 128)
# Test Images:	(125, 128, 128, 3)
# Test Masks:	(125, 128, 128)

# %%
from keras_models.models import ResNet101_deeplabV3
from tensorflow.keras.callbacks import EarlyStopping


EPOCHS = 200
LEARNING_RATE = 1e-3
BATCH_SIZE = 9
early_stopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE)
loss=utils.dice_loss
metrics = ['accuracy']
input_shape = train_images.shape[1:]

train_attr = {
    "lr": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": optimizer.get_config()['name'],
    "loss_fn": loss.get_config()['name']
}

model = ResNet101_deeplabV3(input_shape[0])
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(train_images,
                    train_masks,
                    validation_split = 0.25,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/200
# 394/394 [==============================] - 62s 67ms/step - loss: 0.4221 - accuracy: 0.7999 - val_loss: 0.3903 - val_accuracy: 0.7773
# Epoch 2/200
# 394/394 [==============================] - 23s 57ms/step - loss: 0.3981 - accuracy: 0.8162 - val_loss: 0.4264 - val_accuracy: 0.8208
# Epoch 3/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3905 - accuracy: 0.8211 - val_loss: 0.3816 - val_accuracy: 0.7481
# Epoch 4/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3844 - accuracy: 0.8246 - val_loss: 0.4022 - val_accuracy: 0.8029
# Epoch 5/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3828 - accuracy: 0.8250 - val_loss: 0.4117 - val_accuracy: 0.8196
# Epoch 6/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3780 - accuracy: 0.8287 - val_loss: 0.3674 - val_accuracy: 0.8122
# Epoch 7/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3768 - accuracy: 0.8287 - val_loss: 0.3857 - val_accuracy: 0.8017
# Epoch 8/200
# 394/394 [==============================] - 23s 57ms/step - loss: 0.3722 - accuracy: 0.8315 - val_loss: 0.3682 - val_accuracy: 0.7633
# Epoch 9/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3677 - accuracy: 0.8339 - val_loss: 0.3590 - val_accuracy: 0.8117
# Epoch 10/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3639 - accuracy: 0.8373 - val_loss: 0.4305 - val_accuracy: 0.8222
# Epoch 11/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3609 - accuracy: 0.8381 - val_loss: 0.3582 - val_accuracy: 0.7981
# Epoch 12/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3575 - accuracy: 0.8398 - val_loss: 0.3988 - val_accuracy: 0.8177
# Epoch 13/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3532 - accuracy: 0.8427 - val_loss: 0.3801 - val_accuracy: 0.8234
# Epoch 14/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3486 - accuracy: 0.8443 - val_loss: 0.3535 - val_accuracy: 0.8060
# Epoch 15/200
# 394/394 [==============================] - 23s 57ms/step - loss: 0.3449 - accuracy: 0.8470 - val_loss: 0.3808 - val_accuracy: 0.8125
# Epoch 16/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3437 - accuracy: 0.8479 - val_loss: 0.3541 - val_accuracy: 0.8104
# Epoch 17/200
# 394/394 [==============================] - 23s 57ms/step - loss: 0.3426 - accuracy: 0.8483 - val_loss: 0.3592 - val_accuracy: 0.7843
# Epoch 18/200
# 394/394 [==============================] - 23s 57ms/step - loss: 0.3408 - accuracy: 0.8505 - val_loss: 0.3694 - val_accuracy: 0.8130
# Epoch 19/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3347 - accuracy: 0.8531 - val_loss: 0.3608 - val_accuracy: 0.7910
# Epoch 20/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3313 - accuracy: 0.8550 - val_loss: 0.3548 - val_accuracy: 0.7993
# Epoch 21/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3267 - accuracy: 0.8570 - val_loss: 0.3713 - val_accuracy: 0.7736
# Epoch 22/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3240 - accuracy: 0.8589 - val_loss: 0.3574 - val_accuracy: 0.8062
# Epoch 23/200
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3197 - accuracy: 0.8619 - val_loss: 0.3635 - val_accuracy: 0.8086
# Epoch 24/200
# 393/394 [============================>.] - ETA: 0s - loss: 0.3144 - accuracy: 0.8636Restoring model weights from the end of the best epoch: 14.
# 394/394 [==============================] - 23s 58ms/step - loss: 0.3144 - accuracy: 0.8636 - val_loss: 0.3617 - val_accuracy: 0.8128
# Epoch 24: early stopping

# %%
utils.analyzer(history, model, image_path, mask_path, test_images, test_masks, train_attr)
# Out:
# 4/4 [==============================] - 3s 520ms/step - loss: 0.4129 - accuracy: 0.7803
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
