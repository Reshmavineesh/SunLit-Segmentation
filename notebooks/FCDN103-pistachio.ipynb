# %%
# !rm -rf * .* 2>/dev/null
# !rm -rf ~/.kaggle && mkdir ~/.kaggle
# !echo eyJ1c2VybmFtZSI6InB2dHNlYzB4MSIsImtleSI6IjZlOTYxZmMxYjdhYzU2OTlmNzcwYmFjMjI1NTk4MWIwIn0= | base64 -d > ~/.kaggle/kaggle.json
# !git clone https://github.com/Reshmavineesh/SunLit-Segmentation .
# !git checkout dev
# !./download_dataset.sh
from IPython.display import clear_output
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'; clear_output()
print("Dataset ready")
# Out:
# Dataset ready

# %%
import utils
import tensorflow as tf

image_path = 'dataset/dataset_pistachio_128/color_images/'
mask_path = 'dataset/dataset_pistachio_128/masks/'
n_val = 100

train_images, train_masks, test_images, test_masks = utils.load_dataset(image_path, mask_path, n_val)
print(f"Train Images:\t{train_images.shape}")
print(f"Train Masks:\t{train_masks.shape}")
print(f"Test Images:\t{test_images.shape}")
print(f"Test Masks:\t{test_masks.shape}")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train Images:	(7250, 128, 128, 3)
# Train Masks:	(7250, 128, 128)
# Test Images:	(100, 128, 128, 3)
# Test Masks:	(100, 128, 128)

# %%
from keras_models.models import FCDN103
from tensorflow.keras.callbacks import EarlyStopping

EPOCHS = 200
LEARNING_RATE = 0.001
BATCH_SIZE = 16
early_stopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
loss=utils.dice_loss
metrics = ['accuracy']
input_shape = train_images.shape[1:]

train_attr = {
    "lr": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": optimizer.get_config()['name'],
    "loss_fn": loss.get_config()['name']
}

n_layers_per_block = [4, 5, 7, 10, 12, 15]
n_classes = 1

model = FCDN103(n_classes, input_shape, num_layers_per_block=n_layers_per_block, dropout_rate=0.2, weight_decay=1e-4)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(train_images,
                    train_masks,
                    validation_split = 0.4,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/200
# 272/272 [==============================] - 224s 487ms/step - loss: 0.6993 - accuracy: 0.8452 - val_loss: 0.5513 - val_accuracy: 0.8630
# Epoch 2/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4790 - accuracy: 0.8569 - val_loss: 0.5315 - val_accuracy: 0.8931
# Epoch 3/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4600 - accuracy: 0.8575 - val_loss: 0.4833 - val_accuracy: 0.8919
# Epoch 4/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4531 - accuracy: 0.8592 - val_loss: 0.4727 - val_accuracy: 0.8924
# Epoch 5/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4473 - accuracy: 0.8599 - val_loss: 0.4774 - val_accuracy: 0.8592
# Epoch 6/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4416 - accuracy: 0.8598 - val_loss: 0.5511 - val_accuracy: 0.8949
# Epoch 7/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4365 - accuracy: 0.8599 - val_loss: 0.5434 - val_accuracy: 0.8967
# Epoch 8/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4361 - accuracy: 0.8610 - val_loss: 0.5504 - val_accuracy: 0.8968
# Epoch 9/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4318 - accuracy: 0.8613 - val_loss: 0.4885 - val_accuracy: 0.8954
# Epoch 10/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4315 - accuracy: 0.8621 - val_loss: 0.4895 - val_accuracy: 0.8959
# Epoch 11/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4292 - accuracy: 0.8625 - val_loss: 0.5029 - val_accuracy: 0.8989
# Epoch 12/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4273 - accuracy: 0.8625 - val_loss: 0.4730 - val_accuracy: 0.8906
# Epoch 13/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4312 - accuracy: 0.8623 - val_loss: 0.6340 - val_accuracy: 0.8933
# Epoch 14/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4258 - accuracy: 0.8631 - val_loss: 0.4640 - val_accuracy: 0.8918
# Epoch 15/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4258 - accuracy: 0.8633 - val_loss: 0.4723 - val_accuracy: 0.8891
# Epoch 16/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4233 - accuracy: 0.8641 - val_loss: 0.5314 - val_accuracy: 0.8983
# Epoch 17/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4253 - accuracy: 0.8619 - val_loss: 0.5198 - val_accuracy: 0.8985
# Epoch 18/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4229 - accuracy: 0.8631 - val_loss: 0.4790 - val_accuracy: 0.8985
# Epoch 19/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4224 - accuracy: 0.8638 - val_loss: 0.4585 - val_accuracy: 0.8955
# Epoch 20/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4228 - accuracy: 0.8635 - val_loss: 0.4773 - val_accuracy: 0.8969
# Epoch 21/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4214 - accuracy: 0.8638 - val_loss: 0.4435 - val_accuracy: 0.8878
# Epoch 22/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4218 - accuracy: 0.8638 - val_loss: 0.4483 - val_accuracy: 0.8814
# Epoch 23/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4208 - accuracy: 0.8660 - val_loss: 0.5239 - val_accuracy: 0.8972
# Epoch 24/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4200 - accuracy: 0.8643 - val_loss: 0.5160 - val_accuracy: 0.8977
# Epoch 25/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4185 - accuracy: 0.8651 - val_loss: 0.4418 - val_accuracy: 0.8901
# Epoch 26/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4135 - accuracy: 0.8660 - val_loss: 0.5335 - val_accuracy: 0.8930
# Epoch 27/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4132 - accuracy: 0.8665 - val_loss: 0.5478 - val_accuracy: 0.8923
# Epoch 28/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4150 - accuracy: 0.8649 - val_loss: 0.4449 - val_accuracy: 0.8892
# Epoch 29/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4168 - accuracy: 0.8657 - val_loss: 0.4701 - val_accuracy: 0.8923
# Epoch 30/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4169 - accuracy: 0.8641 - val_loss: 0.4429 - val_accuracy: 0.8906
# Epoch 31/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4138 - accuracy: 0.8651 - val_loss: 0.5173 - val_accuracy: 0.8951
# Epoch 32/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4226 - accuracy: 0.8651 - val_loss: 0.4953 - val_accuracy: 0.8932
# Epoch 33/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4118 - accuracy: 0.8660 - val_loss: 0.6605 - val_accuracy: 0.8898
# Epoch 34/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4115 - accuracy: 0.8667 - val_loss: 0.4856 - val_accuracy: 0.8931
# Epoch 35/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4126 - accuracy: 0.8661 - val_loss: 0.4412 - val_accuracy: 0.8826
# Epoch 36/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4096 - accuracy: 0.8682 - val_loss: 0.4676 - val_accuracy: 0.8991
# Epoch 37/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4113 - accuracy: 0.8671 - val_loss: 0.4389 - val_accuracy: 0.8825
# Epoch 38/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4131 - accuracy: 0.8665 - val_loss: 0.4560 - val_accuracy: 0.8907
# Epoch 39/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4111 - accuracy: 0.8669 - val_loss: 0.5560 - val_accuracy: 0.8972
# Epoch 40/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4124 - accuracy: 0.8665 - val_loss: 0.4492 - val_accuracy: 0.8753
# Epoch 41/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4095 - accuracy: 0.8678 - val_loss: 0.4470 - val_accuracy: 0.8913
# Epoch 42/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4097 - accuracy: 0.8681 - val_loss: 0.4635 - val_accuracy: 0.8820
# Epoch 43/200
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4161 - accuracy: 0.8668 - val_loss: 0.4434 - val_accuracy: 0.8892
# Epoch 44/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4087 - accuracy: 0.8662 - val_loss: 0.4398 - val_accuracy: 0.8953
# Epoch 45/200
# 272/272 [==============================] - 115s 424ms/step - loss: 0.4068 - accuracy: 0.8674 - val_loss: 0.4548 - val_accuracy: 0.8973
# Epoch 46/200
# 272/272 [==============================] - 116s 425ms/step - loss: 0.4092 - accuracy: 0.8673 - val_loss: 0.4529 - val_accuracy: 0.8692
# Epoch 47/200
# 272/272 [==============================] - ETA: 0s - loss: 0.4088 - accuracy: 0.8677Restoring model weights from the end of the best epoch: 37.
# 272/272 [==============================] - 116s 426ms/step - loss: 0.4088 - accuracy: 0.8677 - val_loss: 0.4435 - val_accuracy: 0.8704
# Epoch 47: early stopping

# %%
utils.analyzer(history, model, image_path, mask_path, test_images, test_masks, train_attr)
# Out:
# 4/4 [==============================] - 8s 107ms/step - loss: 0.5165 - accuracy: 0.8875
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
