# %%
# !rm -rf * .* 2>/dev/null
# !rm -rf ~/.kaggle && mkdir ~/.kaggle
# !echo eyJ1c2VybmFtZSI6InB2dHNlYzB4MSIsImtleSI6IjZlOTYxZmMxYjdhYzU2OTlmNzcwYmFjMjI1NTk4MWIwIn0= | base64 -d > ~/.kaggle/kaggle.json
# !git clone https://github.com/Reshmavineesh/SunLit-Segmentation .
# !git checkout dev
# !./download_dataset.sh
from IPython.display import clear_output
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'; clear_output()
print("Dataset ready")
# Out:
# Dataset ready

# %%
import utils
import tensorflow as tf

image_path = 'dataset/dataset_pistachio_128/color_images/'
mask_path = 'dataset/dataset_pistachio_128/masks/'
n_val = 100

train_images, train_masks, test_images, test_masks = utils.load_dataset(image_path, mask_path, n_val)
print(f"Train Images:\t{train_images.shape}")
print(f"Train Masks:\t{train_masks.shape}")
print(f"Test Images:\t{test_images.shape}")
print(f"Test Masks:\t{test_masks.shape}")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train Images:	(7250, 128, 128, 3)
# Train Masks:	(7250, 128, 128)
# Test Images:	(100, 128, 128, 3)
# Test Masks:	(100, 128, 128)

# %%
from keras_models.models import FRRNA
from tensorflow.keras.callbacks import EarlyStopping


EPOCHS = 200
LEARNING_RATE = 0.001
BATCH_SIZE = 16
early_stopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
loss=utils.dice_loss
metrics = ['accuracy']
input_shape = train_images.shape[1:]

train_attr = {
    "lr": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": optimizer.get_config()['name'],
    "loss_fn": loss.get_config()['name']
}

model = FRRNA(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(train_images,
                    train_masks,
                    validation_split = 0.25,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/200
# 340/340 [==============================] - 115s 224ms/step - loss: 0.4222 - accuracy: 0.8507 - val_loss: 0.5102 - val_accuracy: 0.8089
# Epoch 2/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.4066 - accuracy: 0.8635 - val_loss: 0.4860 - val_accuracy: 0.8613
# Epoch 3/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.4035 - accuracy: 0.8653 - val_loss: 0.5094 - val_accuracy: 0.8600
# Epoch 4/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.4007 - accuracy: 0.8669 - val_loss: 0.4974 - val_accuracy: 0.8941
# Epoch 5/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3958 - accuracy: 0.8686 - val_loss: 0.4945 - val_accuracy: 0.8980
# Epoch 6/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3969 - accuracy: 0.8689 - val_loss: 0.4859 - val_accuracy: 0.8929
# Epoch 7/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3959 - accuracy: 0.8690 - val_loss: 0.4380 - val_accuracy: 0.8968
# Epoch 8/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3930 - accuracy: 0.8718 - val_loss: 0.4498 - val_accuracy: 0.8628
# Epoch 9/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3941 - accuracy: 0.8712 - val_loss: 0.4449 - val_accuracy: 0.8923
# Epoch 10/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3877 - accuracy: 0.8732 - val_loss: 0.4395 - val_accuracy: 0.8738
# Epoch 11/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3851 - accuracy: 0.8741 - val_loss: 0.4635 - val_accuracy: 0.9022
# Epoch 12/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3843 - accuracy: 0.8748 - val_loss: 0.4465 - val_accuracy: 0.8686
# Epoch 13/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3823 - accuracy: 0.8760 - val_loss: 0.4298 - val_accuracy: 0.8972
# Epoch 14/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3793 - accuracy: 0.8771 - val_loss: 0.4315 - val_accuracy: 0.8801
# Epoch 15/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3774 - accuracy: 0.8780 - val_loss: 0.4336 - val_accuracy: 0.8813
# Epoch 16/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3735 - accuracy: 0.8792 - val_loss: 0.4282 - val_accuracy: 0.8832
# Epoch 17/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3732 - accuracy: 0.8801 - val_loss: 0.5578 - val_accuracy: 0.8747
# Epoch 18/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3685 - accuracy: 0.8818 - val_loss: 0.4733 - val_accuracy: 0.9009
# Epoch 19/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3648 - accuracy: 0.8835 - val_loss: 0.4358 - val_accuracy: 0.8922
# Epoch 20/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3607 - accuracy: 0.8856 - val_loss: 0.4431 - val_accuracy: 0.8998
# Epoch 21/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3563 - accuracy: 0.8875 - val_loss: 0.4471 - val_accuracy: 0.8973
# Epoch 22/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3503 - accuracy: 0.8899 - val_loss: 0.4545 - val_accuracy: 0.8988
# Epoch 23/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3434 - accuracy: 0.8928 - val_loss: 0.4404 - val_accuracy: 0.8751
# Epoch 24/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3398 - accuracy: 0.8943 - val_loss: 0.5044 - val_accuracy: 0.8980
# Epoch 25/200
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3274 - accuracy: 0.8986 - val_loss: 0.4611 - val_accuracy: 0.9003
# Epoch 26/200
# 340/340 [==============================] - ETA: 0s - loss: 0.3226 - accuracy: 0.9013Restoring model weights from the end of the best epoch: 16.
# 340/340 [==============================] - 72s 212ms/step - loss: 0.3226 - accuracy: 0.9013 - val_loss: 0.4506 - val_accuracy: 0.9006
# Epoch 26: early stopping

# %%
utils.analyzer(history, model, image_path, mask_path, test_images, test_masks, train_attr)
# Out:
# 4/4 [==============================] - 2s 256ms/step - loss: 0.4836 - accuracy: 0.8906
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
