# %%
# !rm -rf * .* 2>/dev/null
# !rm -rf ~/.kaggle && mkdir ~/.kaggle
# !echo eyJ1c2VybmFtZSI6InB2dHNlYzB4MSIsImtleSI6IjZlOTYxZmMxYjdhYzU2OTlmNzcwYmFjMjI1NTk4MWIwIn0= | base64 -d > ~/.kaggle/kaggle.json
# !git clone https://github.com/Reshmavineesh/SunLit-Segmentation .
# !git checkout dev
# !./download_dataset.sh
from IPython.display import clear_output
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'; clear_output()
print("Dataset ready")
# Out:
# Dataset ready

# %%
import utils
import tensorflow as tf

image_path = 'dataset/dataset_tomato_128/color_images/'
mask_path = 'dataset/dataset_tomato_128/masks/'
n_val = 100

train_images, train_masks, test_images, test_masks = utils.load_dataset(image_path, mask_path, n_val)
print(f"Train Images:\t{train_images.shape}")
print(f"Train Masks:\t{train_masks.shape}")
print(f"Test Images:\t{test_images.shape}")
print(f"Test Masks:\t{test_masks.shape}")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train Images:	(4748, 128, 128, 3)
# Train Masks:	(4748, 128, 128)
# Test Images:	(100, 128, 128, 3)
# Test Masks:	(100, 128, 128)

# %%
from keras_models.models import SegNet
from tensorflow.keras.callbacks import EarlyStopping


EPOCHS = 200
LEARNING_RATE = 0.001
BATCH_SIZE = 16
early_stopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
loss=utils.dice_loss
metrics = ['accuracy']
input_shape = train_images.shape[1:]

train_attr = {
    "lr": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": optimizer.get_config()['name'],
    "loss_fn": loss.get_config()['name']
}

model = SegNet(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(train_images,
                    train_masks,
                    validation_split = 0.25,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/200
# 223/223 [==============================] - 89s 282ms/step - loss: 0.5986 - accuracy: 0.6583 - val_loss: 0.5835 - val_accuracy: 0.5231
# Epoch 2/200
# 223/223 [==============================] - 59s 267ms/step - loss: 0.5650 - accuracy: 0.7161 - val_loss: 0.5669 - val_accuracy: 0.7520
# Epoch 3/200
# 223/223 [==============================] - 59s 266ms/step - loss: 0.5381 - accuracy: 0.7431 - val_loss: 0.5036 - val_accuracy: 0.8018
# Epoch 4/200
# 223/223 [==============================] - 59s 267ms/step - loss: 0.5139 - accuracy: 0.7668 - val_loss: 0.4719 - val_accuracy: 0.7224
# Epoch 5/200
# 223/223 [==============================] - 60s 267ms/step - loss: 0.4953 - accuracy: 0.7788 - val_loss: 0.4884 - val_accuracy: 0.7890
# Epoch 6/200
# 223/223 [==============================] - 59s 267ms/step - loss: 0.4833 - accuracy: 0.7830 - val_loss: 0.7953 - val_accuracy: 0.7491
# Epoch 7/200
# 223/223 [==============================] - 59s 266ms/step - loss: 0.4738 - accuracy: 0.7874 - val_loss: 0.4418 - val_accuracy: 0.6938
# Epoch 8/200
# 223/223 [==============================] - 59s 266ms/step - loss: 0.4637 - accuracy: 0.7926 - val_loss: 0.4183 - val_accuracy: 0.7420
# Epoch 9/200
# 223/223 [==============================] - 59s 265ms/step - loss: 0.4576 - accuracy: 0.7945 - val_loss: 0.4462 - val_accuracy: 0.8019
# Epoch 10/200
# 223/223 [==============================] - 59s 265ms/step - loss: 0.4578 - accuracy: 0.7928 - val_loss: 0.4452 - val_accuracy: 0.6561
# Epoch 11/200
# 223/223 [==============================] - 60s 267ms/step - loss: 0.4514 - accuracy: 0.7956 - val_loss: 0.4040 - val_accuracy: 0.7450
# Epoch 12/200
# 223/223 [==============================] - 60s 267ms/step - loss: 0.4474 - accuracy: 0.7950 - val_loss: 0.4078 - val_accuracy: 0.7881
# Epoch 13/200
# 223/223 [==============================] - 60s 268ms/step - loss: 0.4416 - accuracy: 0.7956 - val_loss: 0.3926 - val_accuracy: 0.7609
# Epoch 14/200
