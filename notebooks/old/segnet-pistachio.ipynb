# %%
# !rm -rf * .* 2>/dev/null
# !rm -rf ~/.kaggle && mkdir ~/.kaggle
# !echo eyJ1c2VybmFtZSI6InB2dHNlYzB4MSIsImtleSI6IjZlOTYxZmMxYjdhYzU2OTlmNzcwYmFjMjI1NTk4MWIwIn0= | base64 -d > ~/.kaggle/kaggle.json
# !git clone https://github.com/Reshmavineesh/SunLit-Segmentation .
# !git checkout dev
# !./download_dataset.sh
from IPython.display import clear_output
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'; clear_output()
print("Dataset ready")
# Out:
# Dataset ready

# %%
import utils
import tensorflow as tf

image_path = 'dataset/dataset_pistachio_128/color_images/'
mask_path = 'dataset/dataset_pistachio_128/masks/'
n_val = 200

train_images, train_masks, test_images, test_masks = utils.load_dataset(image_path, mask_path, n_val)
print(f"Train Images:\t{train_images.shape}")
print(f"Train Masks:\t{train_masks.shape}")
print(f"Test Images:\t{test_images.shape}")
print(f"Test Masks:\t{test_masks.shape}")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train Images:	(7150, 128, 128, 3)
# Train Masks:	(7150, 128, 128)
# Test Images:	(7150, 128, 128, 3)
# Test Masks:	(7150, 128, 128)

# %%
from keras_models.models import SegNet
from tensorflow.keras.callbacks import EarlyStopping


EPOCHS = 200
LEARNING_RATE = 0.001
BATCH_SIZE = 16
early_stopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
loss=utils.dice_loss
metrics = ['accuracy']
input_shape = train_images.shape[1:]

train_attr = {
    "lr": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": optimizer.get_config()['name'],
    "loss_fn": loss.get_config()['name']
}

model = SegNet(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(train_images,
                    train_masks,
                    validation_split = 0.25,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/200
# 336/336 [==============================] - 116s 268ms/step - loss: 0.6346 - accuracy: 0.7713 - val_loss: 0.7235 - val_accuracy: 0.4818
# Epoch 2/200
# 336/336 [==============================] - 88s 262ms/step - loss: 0.5952 - accuracy: 0.7986 - val_loss: 0.7230 - val_accuracy: 0.4973
# Epoch 3/200
# 336/336 [==============================] - 88s 262ms/step - loss: 0.5646 - accuracy: 0.8129 - val_loss: 0.8321 - val_accuracy: 0.8807
# Epoch 4/200
# 336/336 [==============================] - 88s 261ms/step - loss: 0.5281 - accuracy: 0.8277 - val_loss: 0.6774 - val_accuracy: 0.6033
# Epoch 5/200
# 336/336 [==============================] - 88s 263ms/step - loss: 0.5248 - accuracy: 0.8276 - val_loss: 0.5734 - val_accuracy: 0.8467
# Epoch 6/200
# 336/336 [==============================] - 92s 274ms/step - loss: 0.4967 - accuracy: 0.8358 - val_loss: 0.6550 - val_accuracy: 0.6482
# Epoch 7/200
# 336/336 [==============================] - 92s 272ms/step - loss: 0.4870 - accuracy: 0.8421 - val_loss: 0.5574 - val_accuracy: 0.8217
# Epoch 8/200
# 336/336 [==============================] - 91s 272ms/step - loss: 0.4802 - accuracy: 0.8432 - val_loss: 0.6517 - val_accuracy: 0.6969
# Epoch 9/200
# 336/336 [==============================] - 94s 281ms/step - loss: 0.4769 - accuracy: 0.8436 - val_loss: 0.5132 - val_accuracy: 0.8897
# Epoch 10/200
# 336/336 [==============================] - 93s 277ms/step - loss: 0.4764 - accuracy: 0.8435 - val_loss: 0.5428 - val_accuracy: 0.8521
# Epoch 11/200
# 336/336 [==============================] - 94s 279ms/step - loss: 0.4909 - accuracy: 0.8348 - val_loss: 0.6292 - val_accuracy: 0.7087
# Epoch 12/200
# 336/336 [==============================] - 93s 277ms/step - loss: 0.4944 - accuracy: 0.8347 - val_loss: 0.5797 - val_accuracy: 0.8715
# Epoch 13/200
# 336/336 [==============================] - 94s 279ms/step - loss: 0.5117 - accuracy: 0.8305 - val_loss: 0.6076 - val_accuracy: 0.8741
# Epoch 14/200
# 336/336 [==============================] - 93s 278ms/step - loss: 0.4823 - accuracy: 0.8434 - val_loss: 0.5625 - val_accuracy: 0.8294
# Epoch 15/200
# 336/336 [==============================] - 93s 278ms/step - loss: 0.4979 - accuracy: 0.8378 - val_loss: 0.5127 - val_accuracy: 0.8663
# Epoch 16/200
# 336/336 [==============================] - 93s 277ms/step - loss: 0.5018 - accuracy: 0.8385 - val_loss: 0.5929 - val_accuracy: 0.8246
# Epoch 17/200
# 336/336 [==============================] - 94s 279ms/step - loss: 0.5164 - accuracy: 0.8276 - val_loss: 0.5258 - val_accuracy: 0.8727
# Epoch 18/200
# 336/336 [==============================] - 92s 275ms/step - loss: 0.4826 - accuracy: 0.8414 - val_loss: 0.5084 - val_accuracy: 0.8689
# Epoch 19/200
# 336/336 [==============================] - 93s 278ms/step - loss: 0.4840 - accuracy: 0.8403 - val_loss: 0.5611 - val_accuracy: 0.7826
# Epoch 20/200
# 336/336 [==============================] - 93s 277ms/step - loss: 0.4863 - accuracy: 0.8384 - val_loss: 0.5147 - val_accuracy: 0.8711
# Epoch 21/200
# 336/336 [==============================] - 93s 278ms/step - loss: 0.4745 - accuracy: 0.8447 - val_loss: 0.5156 - val_accuracy: 0.8853
# Epoch 22/200
# 336/336 [==============================] - 93s 277ms/step - loss: 0.4913 - accuracy: 0.8358 - val_loss: 0.6104 - val_accuracy: 0.7331
# Epoch 23/200
# 336/336 [==============================] - 93s 278ms/step - loss: 0.5157 - accuracy: 0.8233 - val_loss: 0.5814 - val_accuracy: 0.8241
# Epoch 24/200
# 336/336 [==============================] - 93s 276ms/step - loss: 0.5606 - accuracy: 0.7945 - val_loss: 0.5985 - val_accuracy: 0.7885
# Epoch 25/200
# 336/336 [==============================] - 93s 278ms/step - loss: 0.5484 - accuracy: 0.7987 - val_loss: 0.5811 - val_accuracy: 0.7867
# Epoch 26/200
# 336/336 [==============================] - 93s 277ms/step - loss: 0.5554 - accuracy: 0.7920 - val_loss: 0.6013 - val_accuracy: 0.7933
# Epoch 27/200
# 336/336 [==============================] - 93s 277ms/step - loss: 0.5368 - accuracy: 0.7991 - val_loss: 0.5508 - val_accuracy: 0.8568
# Epoch 28/200
# 336/336 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.8389Restoring model weights from the end of the best epoch: 18.
# 336/336 [==============================] - 94s 280ms/step - loss: 0.4656 - accuracy: 0.8389 - val_loss: 0.5248 - val_accuracy: 0.8828
# Epoch 28: early stopping

# %%
utils.analyzer(history, model, image_path, mask_path, test_images, test_masks, train_attr)
# Out:
# 224/224 [==============================] - 76s 335ms/step - loss: 0.4876 - accuracy: 0.8472
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
