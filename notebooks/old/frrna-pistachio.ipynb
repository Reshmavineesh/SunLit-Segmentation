# %%
# !rm -rf * .* 2>/dev/null
# !rm -rf ~/.kaggle && mkdir ~/.kaggle
# !echo eyJ1c2VybmFtZSI6InB2dHNlYzB4MSIsImtleSI6IjZlOTYxZmMxYjdhYzU2OTlmNzcwYmFjMjI1NTk4MWIwIn0= | base64 -d > ~/.kaggle/kaggle.json
# !git clone https://github.com/Reshmavineesh/SunLit-Segmentation .
# !git checkout dev
# !./download_dataset.sh
from IPython.display import clear_output
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'; clear_output()
print("Dataset ready")
# Out:
# Dataset ready

# %%
import utils
import tensorflow as tf

image_path = 'dataset/dataset_pistachio_128/color_images/'
mask_path = 'dataset/dataset_pistachio_128/masks/'
n_val = 200

train_images, train_masks, test_images, test_masks = utils.load_dataset(image_path, mask_path, n_val)
print(f"Train Images:\t{train_images.shape}")
print(f"Train Masks:\t{train_masks.shape}")
print(f"Test Images:\t{test_images.shape}")
print(f"Test Masks:\t{test_masks.shape}")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Train Images:	(7150, 128, 128, 3)
# Train Masks:	(7150, 128, 128)
# Test Images:	(7150, 128, 128, 3)
# Test Masks:	(7150, 128, 128)

# %%
from keras_models.models import FRRNA
from tensorflow.keras.callbacks import EarlyStopping


EPOCHS = 200
LEARNING_RATE = 0.001
BATCH_SIZE = 16
early_stopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
loss=utils.dice_loss
metrics = ['accuracy']
input_shape = train_images.shape[1:]

train_attr = {
    "lr": LEARNING_RATE,
    "batch_size": BATCH_SIZE,
    "optimizer": optimizer.get_config()['name'],
    "loss_fn": loss.get_config()['name']
}

model = FRRNA(input_shape)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit(train_images,
                    train_masks,
                    validation_split = 0.25,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks=[early_stopper])
# Out:
# Epoch 1/200
# 336/336 [==============================] - 110s 220ms/step - loss: 0.4165 - accuracy: 0.8580 - val_loss: 0.5770 - val_accuracy: 0.7170
# Epoch 2/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.4057 - accuracy: 0.8647 - val_loss: 0.5280 - val_accuracy: 0.8154
# Epoch 3/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.4037 - accuracy: 0.8656 - val_loss: 0.4995 - val_accuracy: 0.8351
# Epoch 4/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.4006 - accuracy: 0.8677 - val_loss: 0.4537 - val_accuracy: 0.8744
# Epoch 5/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3972 - accuracy: 0.8679 - val_loss: 0.4650 - val_accuracy: 0.9015
# Epoch 6/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3963 - accuracy: 0.8701 - val_loss: 0.4532 - val_accuracy: 0.8552
# Epoch 7/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3920 - accuracy: 0.8714 - val_loss: 0.5202 - val_accuracy: 0.8921
# Epoch 8/200
# 336/336 [==============================] - 71s 211ms/step - loss: 0.3914 - accuracy: 0.8717 - val_loss: 0.4314 - val_accuracy: 0.9002
# Epoch 9/200
# 336/336 [==============================] - 71s 211ms/step - loss: 0.3909 - accuracy: 0.8725 - val_loss: 0.4173 - val_accuracy: 0.8969
# Epoch 10/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3883 - accuracy: 0.8729 - val_loss: 0.4266 - val_accuracy: 0.8891
# Epoch 11/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3853 - accuracy: 0.8751 - val_loss: 0.4308 - val_accuracy: 0.8909
# Epoch 12/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3822 - accuracy: 0.8760 - val_loss: 0.4205 - val_accuracy: 0.8911
# Epoch 13/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3845 - accuracy: 0.8759 - val_loss: 0.4276 - val_accuracy: 0.9039
# Epoch 14/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3794 - accuracy: 0.8779 - val_loss: 0.4294 - val_accuracy: 0.8959
# Epoch 15/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3760 - accuracy: 0.8789 - val_loss: 0.4283 - val_accuracy: 0.8825
# Epoch 16/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3720 - accuracy: 0.8803 - val_loss: 0.4260 - val_accuracy: 0.8927
# Epoch 17/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3676 - accuracy: 0.8822 - val_loss: 0.4502 - val_accuracy: 0.8889
# Epoch 18/200
# 336/336 [==============================] - 71s 210ms/step - loss: 0.3675 - accuracy: 0.8825 - val_loss: 0.4561 - val_accuracy: 0.8701
# Epoch 19/200
# 335/336 [============================>.] - ETA: 0s - loss: 0.3629 - accuracy: 0.8845Restoring model weights from the end of the best epoch: 9.
# 336/336 [==============================] - 71s 211ms/step - loss: 0.3630 - accuracy: 0.8845 - val_loss: 0.4293 - val_accuracy: 0.8986
# Epoch 19: early stopping

# %%
utils.analyzer(history, model, image_path, mask_path, test_images, test_masks, train_attr)
# Out:
# 224/224 [==============================] - 28s 119ms/step - loss: 0.3975 - accuracy: 0.8829
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
